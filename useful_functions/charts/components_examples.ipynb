# %%
# %matplotlib widget

# %%
import pandas as pd
import seaborn as sns
sns.set_theme()

# %%
from components_and_line_chart import draw_components_and_line_chart

# %%
cols = pd.Index(["a","b","c"], name="category")
idx = pd.date_range(start="2019-01", end="2024-12", freq="ME", name="date")
df = pd.DataFrame(index=idx, columns=cols, dtype=float)
df["a"] = 1.
df["b"] = 2.
df["c"] = 3.
df.loc['2024':,"c"] = -0.5
df
# Out:
# category      a    b    c
# date
# 2019-01-31  1.0  2.0  3.0
# 2019-02-28  1.0  2.0  3.0
# 2019-03-31  1.0  2.0  3.0
# 2019-04-30  1.0  2.0  3.0
# 2019-05-31  1.0  2.0  3.0
# ...         ...  ...  ...
# 2024-07-31  1.0  2.0 -0.5
# 2024-08-31  1.0  2.0 -0.5
# 2024-09-30  1.0  2.0 -0.5
# 2024-10-31  1.0  2.0 -0.5
# 2024-11-30  1.0  2.0 -0.5
#
# [71 rows x 3 columns]

# %%
draw_components_and_line_chart(df)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
draw_components_and_line_chart(df, total_line_label="HICP")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
draw_components_and_line_chart(df, total_line_label="HICP", component_design="area")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
